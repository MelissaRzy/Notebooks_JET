# %%
pip install cartopy
# Out:
# Requirement already satisfied: cartopy in /opt/conda/lib/python3.11/site-packages (0.23.0)
# Requirement already satisfied: numpy>=1.21 in /opt/conda/lib/python3.11/site-packages (from cartopy) (1.26.2)
# Requirement already satisfied: matplotlib>=3.5 in /opt/conda/lib/python3.11/site-packages (from cartopy) (3.8.1)
# Requirement already satisfied: shapely>=1.7 in /opt/conda/lib/python3.11/site-packages (from cartopy) (2.0.2)
# Requirement already satisfied: packaging>=20 in /opt/conda/lib/python3.11/site-packages (from cartopy) (23.2)
# Requirement already satisfied: pyshp>=2.3 in /opt/conda/lib/python3.11/site-packages (from cartopy) (2.3.1)
# Requirement already satisfied: pyproj>=3.3.1 in /opt/conda/lib/python3.11/site-packages (from cartopy) (3.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.5->cartopy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.5->cartopy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.5->cartopy) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.5->cartopy) (1.4.5)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.5->cartopy) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.5->cartopy) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.5->cartopy) (2.8.2)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from pyproj>=3.3.1->cartopy) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.5->cartopy) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install h5netcdf
# Out:
# Requirement already satisfied: h5netcdf in /opt/conda/lib/python3.11/site-packages (1.3.0)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.11/site-packages (from h5netcdf) (3.11.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from h5netcdf) (23.2)
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/lib/python3.11/site-packages (from h5py->h5netcdf) (1.26.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xarray
# Out:
# Requirement already satisfied: xarray in /opt/conda/lib/python3.11/site-packages (2024.5.0)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/lib/python3.11/site-packages (from xarray) (1.26.2)
# Requirement already satisfied: packaging>=23.1 in /opt/conda/lib/python3.11/site-packages (from xarray) (23.2)
# Requirement already satisfied: pandas>=2.0 in /opt/conda/lib/python3.11/site-packages (from xarray) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas>=2.0->xarray) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=2.0->xarray) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=2.0->xarray) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.0->xarray) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install cftime
# Out:
# Requirement already satisfied: cftime in /opt/conda/lib/python3.11/site-packages (1.6.3)
# Requirement already satisfied: numpy>1.13.3 in /opt/conda/lib/python3.11/site-packages (from cftime) (1.26.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install cmcrameri
# Out:
# Requirement already satisfied: cmcrameri in /opt/conda/lib/python3.11/site-packages (1.9)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.11/site-packages (from cmcrameri) (3.8.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from cmcrameri) (1.26.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from cmcrameri) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib->cmcrameri) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib->cmcrameri) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib->cmcrameri) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib->cmcrameri) (1.4.5)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib->cmcrameri) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib->cmcrameri) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib->cmcrameri) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->cmcrameri) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importamos librerìas que vamos a usar
import xarray as xr
import numpy as np
import datetime
import matplotlib.pyplot as plt
import pandas as pd
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.util import add_cyclic_point
import math
from cmcrameri import cm

# %%
# Funciòn para mapear contourf con vectores de viento
def contour_f(data,ua,va,levels=np.arange(0,11),ccmap='PuBu',extend='max',limite_NS=42,clevels=np.arange(230,300,15),titulo='OLR y pr',cbarlabel='pr  [mm day$^{-1}$]'):
    lons,lats=data.lon,data.lat
    Lon,Lat=np.meshgrid(ua["lon"],ua["lat"])
    data, lon = add_cyclic_point(data, coord=lons)
    #contourdata, lon = add_cyclic_point(contourdata, coord=lons)
    fig = plt.figure(figsize=(10, 6))
    ax = plt.axes(projection=ccrs.PlateCarree())
    ax.coastlines()
    ax.add_feature(cfeature.BORDERS, linestyle=':')
    cs=ax.contourf(lon,lats,data,levels=levels,cmap=ccmap,extend=extend,transform=ccrs.PlateCarree(),alpha=0.9)
    #cc=ax.contour(lon,lats,contourdata,levels=clevels,colors='k',transform=ccrs.PlateCarree())
    #ax.clabel(cc, cc.levels, inline=True, fontsize=10)
    ax.set_extent([-180,180, -limite_NS, limite_NS], crs=ccrs.PlateCarree())
    ax.quiver(Lon[::3,::3],Lat[::3,::3], ua.squeeze()[::3,::3], va.squeeze()[::3,::3], transform=ccrs.PlateCarree(),color="black")
    gl=ax.gridlines(draw_labels=True,color='gray', alpha=0.5, linestyle='--')
    gl.top_labels = False
    gl.right_labels = True
    gl.xlabel_style = {'size': 13}
    gl.ylabel_style = {'size': 13}
    plt.title(titulo,fontsize=13)
    plt.tight_layout()
    plt.subplots_adjust(bottom=0.1)
    cbar=plt.colorbar(cs,orientation='horizontal',fraction=0.046, pad=0.06)
    cbar.ax.set_xlabel(cbarlabel)

# %%
# Función para mapear contourf con contour
def contour(data,contourdata,levels=np.arange(0,11),ccmap='PuBu',extend='max',limite_NS=42,clevels=np.arange(230,300,15),titulo='OLR y pr',cbarlabel='pr  [mm day$^{-1}$]'):
    lons,lats=data.lon,data.lat
    data, lon = add_cyclic_point(data, coord=lons)
    contourdata, lon = add_cyclic_point(contourdata, coord=lons)
    fig = plt.figure(figsize=(10, 6))
    ax = plt.axes(projection=ccrs.Robinson())
    ax.coastlines()
    ax.add_feature(cfeature.BORDERS, linestyle=':')
    cs=ax.contourf(lon,lats,data,levels=levels,cmap=ccmap,extend=extend,transform=ccrs.PlateCarree(),alpha=0.9)
    cc=ax.contour(lon,lats,contourdata,levels=clevels,colors='k',transform=ccrs.PlateCarree())
    ax.clabel(cc, cc.levels, inline=True, fontsize=10)
    ax.set_extent([-180,180, -limite_NS, limite_NS], crs=ccrs.PlateCarree())
    gl=ax.gridlines(draw_labels=True,color='gray', alpha=0.5, linestyle='--')
    gl.top_labels = False
    gl.right_labels = True
    gl.xlabel_style = {'size': 13}
    gl.ylabel_style = {'size': 13}
    plt.title(titulo,fontsize=13)
    plt.tight_layout()
    plt.subplots_adjust(bottom=0.1)
    cbar=plt.colorbar(cs,orientation='horizontal',fraction=0.046, pad=0.06)
    cbar.ax.set_xlabel(cbarlabel)

# %% [markdown]
# En este notebook se hará el análisis del viento a 200 hPa en la simulación histórica y la del escenario ssp585, además de la diferencia entre ambas.

# %% [markdown]
# ---
# ### **<font color="Purple"> Datos históricos de viento zonal en DJF</font>**
# ---

# %%
# Leer los archivos de viento históricos
u_filename='ua_Amon_HadGEM3-GC31-LL_historical_r1i1p1f3_gn_195001-201412.nc'
v_filename='va_Amon_HadGEM3-GC31-LL_historical_r1i1p1f3_gn_195001-201412.nc'

# %%
# Abrir archivos y seleccionar variables a usar 
u_ds=xr.open_dataset(u_filename)
ua=u_ds['ua']  #viento zonal
plevu=u_ds['plev'] #presiones
v_ds=xr.open_dataset(v_filename)
va=v_ds['va']
plevv=v_ds['plev']

# %%
#Seleccionar solo 200 hPa y de 1979 a 2014
ua200hPa = ua.sel(plev=20000).where(ua.time.dt.year >= 1979, drop=True)
va200hPa = va.sel(plev=20000).where(va.time.dt.year >= 1979, drop=True)

# %%
# Calcular promedio estacional de u,v y seleccionar DJF
ua_estacion=ua200hPa.groupby(ua200hPa.time.dt.season).mean(dim='time') 
ua_DJF = ua_estacion[0]
va_estacion=va200hPa.groupby(va200hPa.time.dt.season).mean(dim='time') 
va_DJF = va_estacion[0]

# %%
#magnitud de vector con componentes u,v
magnitudDJF = np.sqrt(ua_DJF**2 + va_DJF**2)

# %%
# Mapear la magnitud del viento zonal en DJF
contour_f(magnitudDJF,ua_DJF,va_DJF,levels=np.arange(5,75),ccmap='RdPu',extend='max',limite_NS=75,clevels=np.arange(5,75,15),titulo=
      'Climatología del viento zonal durante el invierno boreal a 200 hPa \n Simulación histórica (1979-2014)',cbarlabel='Viento zonal [m $s^{-1}$]')
#plt.savefig('historical_200hPa.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ----
# ### **<font color="Purple"> Datos escenario ssp585 de viento zonal en DJF</font>**
# ---

# %%
# Leer archivo ssp585
u_filename585 = 'ua_Amon_HadGEM3-GC31-LL_ssp585_r1i1p1f3_gn_205001-210012.nc'
v_filename585='va_Amon_HadGEM3-GC31-LL_ssp585_r1i1p1f3_gn_205001-210012.nc'

# %%
# Seleccionar variables del archivo ssp585
u_ds585=xr.open_dataset(u_filename585)
ua585=u_ds585['ua']
v_ds585=xr.open_dataset(v_filename585)
va585=v_ds585['va']

# %%
#ua_585=ua585.where(ua585.time.dt.year>2069) #solo periodo de 2070 a 2100
#Seleccionar solo el nivel de 200 hPa
ua2070 = ua585.sel(plev=20000).where(ua585.time.dt.year >= 2070, drop=True)
va2070 = va585.sel(plev=20000).where(va585.time.dt.year >= 2070, drop=True)

# %%
# Calcular promedio estacional y selecionar DJF
ua_585_estacion=ua2070.groupby(ua2070.time.dt.season).mean(dim='time') 
ua_585_DJF = ua_585_estacion[0]
va_585_estacion=va2070.groupby(va2070.time.dt.season).mean(dim='time') 
va_585_DJF = va_585_estacion[0]

# %%
#magnitud de vector con componentes u,v
magnitud585 = np.sqrt(ua_585_DJF**2 + va_585_DJF**2)

# %%
#Llamar la funciòn contour_f para que nos haga el mapa
contour_f(magnitud585,ua_585_DJF,va_585_DJF,levels=np.arange(0,75),ccmap='RdPu',extend='max',limite_NS=75,clevels=np.arange(5,75,15),titulo=
      'Climatología del viento zonal a 200 hPa durante el invierno boreal\n Simulación escenario ssp585 (2070-2100)',cbarlabel='Viento zonal [m $s^{-1}$]')
#plt.savefig('ssp585_200hPa.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ---
# ### **<font color="Purple"> Diferencia de ambas simulaciones para DJF</font>**
# ---

# %%
# Mapeamos la diferencia entre ambas simulaciones en el invierno boreal   
contour(magnitud585-magnitudDJF,magnitud585-magnitudDJF,levels=np.arange(-15,15),ccmap='PiYG',extend='both',limite_NS=75,clevels=np.arange(-15,15,5),titulo=
      'Diferencia entre viento zonal (a 200 hPa) \n Histórica vs ssp585 ',cbarlabel='Viento zonal [m $s^{-1}$]')
plt.savefig('diferencia_200hPa.png', dpi=300, bbox_inches='tight')
