# %%
pip install cartopy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install h5netcdf
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xarray
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install cftime
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install cmcrameri
# Out:
# ...
#   Using cached cmcrameri-1.9-py3-none-any.whl.metadata (4.6 kB)
# ...
# Using cached cmcrameri-1.9-py3-none-any.whl (277 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install toolz
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import xarray as xr
import numpy as np
import datetime
import matplotlib.pyplot as plt
import pandas as pd
import cftime

# %%
# file = 'u_daily_500_200_1979-2024.nc' #16802
# file = 'v_wind_1979-2024_MSRG.nc' #16802
# file = 't2mC_1979_2024.nc' #16802
# file = 'gph_1979-2024.nc' #16802
# file = 'va_day_HadGEM3-GC31-LL_historical_r1i1p1f3_gn_20000101-20141230.nc'
# file = 'u_daily_500_200_1979-2024.nc'
# file = 'uaday200hpa_99_mx.nc'
# file = 'okva_day_HadGEM3-GC31-LL_historical_r1i1p1f3_gn_19790101-19991230.nc'
# file = 'va_day_250hpa_HadGEM3-1979_2014.nc'
# file = 'uday_250hpa_HG_1979_2014.nc'
# file = 't2mC_1979_2024.nc'
# file = 't2m_1979-2024_large.nc'
# file = '../datasetsok/gph_idx_std+.nc'
# file = '../datasetsok/t2mE5_idx_std2-.nc'
# file = '../datasetsok/gph_idx_std-.nc'
# file = '../datasetsok/uE5_idx_std2+.nc'
# file =  '../datasetsok/zg500_idx_std+.nc'
# file = '../datasetsok/tasHG_idx_std-.nc'
# file = '../datasetsok/tasHG_idx_std+.nc'
# file = '../datasetsok/zg500_idx_std-.nc'
# file = '../datasetsok/vHG_idx_std2+.nc'
file = '../datasetsok/uHG_idx_std2-.nc'

# %%
u = xr.open_dataset(file)#,decode_times=False)
u
# u['t2m'].values
# a = u.sel(time=u.time.dt.year==1999)#plev=25000)#,drop=True)
# Out:
# <xarray.Dataset> Size: 12MB
# Dimensions:    (time: 3578, lon: 33, lat: 25)
# Coordinates:
#   * time       (time) object 29kB 1979-01-07 00:00:00 ... 2014-12-30 00:00:00
#   * lon        (lon) float64 264B 232.5 234.4 236.2 238.1 ... 288.8 290.6 292.5
#   * lat        (lat) float64 200B 10.0 11.25 12.5 13.75 ... 37.5 38.75 40.0
#     plev       (time) float64 29kB ...
#     dayofyear  (time) int64 29kB ...
# Data variables:
#     ua         (time, lat, lon) float32 12MB ...

# %%
t2mCelsius = u -273.15

# %%
t2mCelsius1 = u['t2m'] -273.15

# %%
t2mCelsius.to_netcdf('t2mC_1979_2024.nc')
