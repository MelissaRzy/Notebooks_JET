# %%
pip install xarray
# Out:
# Requirement already satisfied: xarray in /opt/conda/lib/python3.11/site-packages (2025.7.0)
# Requirement already satisfied: numpy>=1.26 in /home/jovyan/.local/lib/python3.11/site-packages (from xarray) (1.26.4)
# Requirement already satisfied: packaging>=24.1 in /opt/conda/lib/python3.11/site-packages (from xarray) (25.0)
# Requirement already satisfied: pandas>=2.2 in /opt/conda/lib/python3.11/site-packages (from xarray) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas>=2.2->xarray) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=2.2->xarray) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas>=2.2->xarray) (2024.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.2->xarray) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install toolz
# Out:
# Requirement already satisfied: toolz in /opt/conda/lib/python3.11/site-packages (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install netcdf4
# Out:
# Requirement already satisfied: netcdf4 in /home/jovyan/.local/lib/python3.11/site-packages (1.7.1.post2)
# Requirement already satisfied: cftime in /opt/conda/lib/python3.11/site-packages (from netcdf4) (1.6.4.post1)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from netcdf4) (2023.7.22)
# Requirement already satisfied: numpy in /home/jovyan/.local/lib/python3.11/site-packages (from netcdf4) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install cartopy
# Out:
# Requirement already satisfied: cartopy in /opt/conda/lib/python3.11/site-packages (0.24.1)
# Requirement already satisfied: numpy>=1.23 in /home/jovyan/.local/lib/python3.11/site-packages (from cartopy) (1.26.4)
# Requirement already satisfied: matplotlib>=3.6 in /opt/conda/lib/python3.11/site-packages (from cartopy) (3.9.2)
# Requirement already satisfied: shapely>=1.8 in /opt/conda/lib/python3.11/site-packages (from cartopy) (2.0.6)
# Requirement already satisfied: packaging>=21 in /opt/conda/lib/python3.11/site-packages (from cartopy) (25.0)
# Requirement already satisfied: pyshp>=2.3 in /opt/conda/lib/python3.11/site-packages (from cartopy) (2.3.1)
# Requirement already satisfied: pyproj>=3.3.1 in /opt/conda/lib/python3.11/site-packages (from cartopy) (3.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy) (1.4.7)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy) (2.8.2)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from pyproj>=3.3.1->cartopy) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.6->cartopy) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install h5netcdf
# Out:
# Requirement already satisfied: h5netcdf in /opt/conda/lib/python3.11/site-packages (1.6.3)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.11/site-packages (from h5netcdf) (3.14.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from h5netcdf) (25.0)
# Requirement already satisfied: numpy>=1.19.3 in /home/jovyan/.local/lib/python3.11/site-packages (from h5py->h5netcdf) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install cftime
# Out:
# Requirement already satisfied: cftime in /opt/conda/lib/python3.11/site-packages (1.6.4.post1)
# Requirement already satisfied: numpy>1.13.3 in /home/jovyan/.local/lib/python3.11/site-packages (from cftime) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install cfgrib
# Out:
# Requirement already satisfied: cfgrib in /opt/conda/lib/python3.11/site-packages (0.9.15.0)
# Requirement already satisfied: attrs>=19.2 in /opt/conda/lib/python3.11/site-packages (from cfgrib) (23.1.0)
# Requirement already satisfied: click in /home/jovyan/.local/lib/python3.11/site-packages (from cfgrib) (8.1.7)
# Requirement already satisfied: eccodes>=0.9.8 in /opt/conda/lib/python3.11/site-packages (from cfgrib) (2.42.0)
# Requirement already satisfied: numpy in /home/jovyan/.local/lib/python3.11/site-packages (from cfgrib) (1.26.4)
# Requirement already satisfied: cffi in /opt/conda/lib/python3.11/site-packages (from eccodes>=0.9.8->cfgrib) (1.16.0)
# Requirement already satisfied: findlibs in /opt/conda/lib/python3.11/site-packages (from eccodes>=0.9.8->cfgrib) (0.1.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi->eccodes>=0.9.8->cfgrib) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
import xarray as xr
import numpy as np
import datetime
import matplotlib.pyplot as plt
import pandas as pd
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import seaborn as sns
import cftime

# %%
def lineplot_setup(xmin, xmax, xlab, ylab, ymin=None, ymax=None, title=None, ax=None):
    if ax is None:
        ax = plt.gca()  # Usa el eje actual si no se pasa uno

    ax.set_xlim([xmin, xmax])
    if ymin is not None and ymax is not None:
        ax.set_ylim([ymin, ymax])
    
    ax.grid(linestyle='--', alpha=0.66)
    ax.minorticks_on()
    
    ax.tick_params(axis='both', labelsize=10)
    ax.set_xlabel(xlab, fontsize=13)
    ax.set_ylabel(ylab, fontsize=13)
    ax.set_title(title, fontsize=15)

# %% [markdown]
# ### **<font color="Purple"> Datos de ERA5 </font>**

# %% [markdown]
# ### **<font color="olive"> CAOs</font>**

# %%
CAOsE5 = pd.read_csv('datasetsok/fechasCAO_E5.csv',parse_dates=['fecha'])

# %% [markdown]
# ### **<font color="olive"> Temperatura</font>**

# %%
filet2m_era5 = 'datasetsok/t2mC_1979_2024.nc'

# %%
t2m_ds=xr.open_dataset(filet2m_era5)
t2m=t2m_ds['t2m']
t2m['time'] = t2m.time.dt.floor("D")

# %%
t2m_inviernos = t2m.sel(time=t2m['time.month'].isin([12, 1, 2]))
t2m_inviernos['time'] = t2m_inviernos.time.dt.floor("D")

# %% [markdown]
# ##### **<font color="olive"> Geopotencial </font>**

# %% [markdown]
# ##### **<font color="olive"> Concat de índice >1 y valores de gph </font>**

# %%
# esta es la base que tiene solo las fechas cuando el índice > 1
# es también las anomalías del ciclo anual de gph

# %%
idxp_gph_file = 'datasetsok/gph_idx_std+.nc'

# %%
idxp_gph_ds = xr.open_dataset(idxp_gph_file)
idxp_gph = idxp_gph_ds['z']
idxp_gph = idxp_gph.sel(pressure_level=500)
idxp_gph['time'] = idxp_gph.time.dt.floor("D")

# %% [markdown]
# ##### **<font color="olive"> Concat de índice <-1 y valores de gph </font>**

# %%
idxn_gph_file = 'datasetsok/gph_idx_std-.nc'

# %%
idxn_gph_ds = xr.open_dataset(idxn_gph_file)
idxn_gph = idxn_gph_ds['z']
idxn_gph = idxn_gph.sel(pressure_level=500)

# %%
idxn_gph_vals = idxn_gph.mean(dim='time')
idxn_gph_seasons = idxn_gph.groupby(idxn_gph.time.dt.season).mean(dim='time') #DJF
idxn_gph_djf = idxn_gph_seasons[0]

# %% [markdown]
# ##### **<font color="olive"> Promedio de área </font>**

# %%
#Elegir un cuadro de 4x4
latitudes = t2m.sel(latitude=slice(27,22))
longitudes = latitudes.sel(longitude=slice(-105, -98))

# %%
weights = np.cos(np.deg2rad(latitudes.latitude))
weights.name = "weights"

# %%
t2m_weighted = longitudes.weighted(weights)

# %%
promareaE5 = t2m_weighted.mean(['longitude','latitude'])

# %%
#desestacionalizar el promedio de área

# %%
t2m_climday = promareaE5.groupby('time.dayofyear').mean('time') #este es el ciclo anual

# %%
t2mclimdaysuav = t2m_climday.rolling(dayofyear=7, center=True, min_periods=1).mean()

# %%
anomaliasdayE5 = promareaE5.groupby('time.dayofyear') - t2mclimdaysuav

# %%
# anomaliasdayE5.to_netcdf('datasetsok/anomT_4x4_E5.nc')

# %% [markdown]
# ##### fechas CAO en el promedio de área

# %%
anomaliasdayE5['time'] = pd.to_datetime(anomaliasdayE5['time'].values).normalize()
lista_fechasE5 = CAOsE5['fecha'].dt.normalize()

# %%
anomsCAO_E5 = anomaliasdayE5.sel(time=anomaliasdayE5.time.isin(lista_fechasE5))

# %%
prom_anomCAO_E5 = anomsCAO_E5.mean(dim='time')
prom_anomCAO_E5
# Out:
# <xarray.DataArray 't2m' ()> Size: 8B
# array(-7.32107687)

# %% [markdown]
# ##### **<font color="olive"> Temperatura e índice >1 (con valores de gph) </font>**

# %%
missing_times_T = np.setdiff1d(idxp_gph.time.values, anomaliasdayE5.time.values)
# print(missing_times_T)
len(missing_times_T)
# Out:
# 0

# %%
t2m_ds_idxp = anomaliasdayE5.reindex(time=idxp_gph.time) #del campo de temperatura solo agarró las fechas cuando índice es positivo

# %% [markdown]
# ##### **<font color="olive"> Temperatura e índice <-1 (con valores de gph) </font>**

# %%
missing_times_Tn = np.setdiff1d(idxn_gph.time.values, anomaliasdayE5.time.values)
# print(missing_times_Tn)
len(missing_times_Tn)
# Out:
# 0

# %%
t2m_ds_idxn = anomaliasdayE5.reindex(time=idxn_gph.time)  #del campo de temperatura solo agarró las fechas cuando índice es negativo

# %%
t2m_pos_mean = t2m_ds_idxp.to_series()
t2m_neg_mean = t2m_ds_idxn.to_series()

df = pd.DataFrame({
    "Anomalía": pd.concat([t2m_pos_mean, t2m_neg_mean]),
    "Fase": (
        ["PNA positivo"] * len(t2m_pos_mean) +
        ["PNA negativo"] * len(t2m_neg_mean)
    )
})

# %%
# Separar los datos por fase
pos_data = dfHG[dfHG["Fase"] == "PNA+"]["Anomalía"]
neg_data = dfHG[dfHG["Fase"] == "PNA-"]["Anomalía"]

plt.figure(figsize=(7, 4))
sns.kdeplot(pos_data, label="PNA+", color="red", fill=True, linewidth=1.5, alpha=0.6)
sns.kdeplot(neg_data, label="PNA-", color="blue", fill=True, linewidth=1.5, alpha=0.6)

valor_prom_anom = prom_anomCAO_E5.item()
lineplot_setup(pos_data.min()-1, neg_data.max()+2, 
               xlab='Anomalía de temperatura (°C)', ylab='Densidad',
               title='Anomalías de temperatura por fase de PNA')

# Agregar línea vertical con el valor del promedio
plt.axvline(valor_prom_anom, color="black", linestyle="--", linewidth=2, label=f"Media HadGEM3 = {valor_prom_anom:.2f}")
plt.legend()
plt.show()

# %% [markdown]
# ### **<font color="Purple"> Datos de HadGEM3</font>**

# %% [markdown]
# ### **<font color="olive"> CAOs </font>**

# %%
CAOsHG = pd.read_csv('datasetsok/fechasCAOs_HG.csv',parse_dates=['fecha'])

# %% [markdown]
# ### **<font color="olive"> Temperatura </font>**

# %%
tas_file = 'datasetsok/tasday79.nc'

# %%
#archivo historical
tas_ds=xr.open_dataset(tas_file)
tas=tas_ds['tas']
tas['time'] = tas.time.dt.floor("D")

# %%
tas_inviernos = tas.sel(time=tas['time.month'].isin([12, 1, 2]))

# %% [markdown]
# ##### **<font color="olive"> Promedio de área </font>**

# %%
#Elegir un cuadro de 4x4
latitudes = tas.sel(lat=slice(22,27))
longitudes = latitudes.sel(lon=slice(255,262))

# %%
weights = np.cos(np.deg2rad(latitudes.lat))
weights.name = "weights"

# %%
tas_weighted = longitudes.weighted(weights)

# %%
promareaHG = tas_weighted.mean(['lon','lat'])

# %%
#desestacionalizar promedio de área

# %%
tas_climday = promareaHG.groupby('time.dayofyear').mean('time') #este es el ciclo anual

# %%
tasclimdaysuav = tas_climday.rolling(dayofyear=7, center=True, min_periods=1).mean()

# %%
anomaliasdayHG = promareaHG.groupby('time.dayofyear') - tasclimdaysuav

# %%
# anomaliasdayHG.to_netcdf('datasetsok/anomT_4x4_HG.nc')

# %%
# Convertir a cftime.Datetime360Day y quitar fechas inválidas
def a_360(fecha):
    try:
        return cftime.Datetime360Day(fecha.year, fecha.month, fecha.day)
    except ValueError:
        return None  # Si no se puede, por ejemplo 29-feb no bisiesto

# Crear nueva columna con las fechas convertidas
CAOsHG["fecha360"] = CAOsHG["fecha"].apply(a_360)

# Eliminar las fechas no convertibles
fechasCAO_validas = fechasCAO.dropna(subset=["fecha360"])

# Lista final de fechas
lista_fechas_360 = fechasCAO_validas["fecha360"].tolist()

# %%
anomsCAO_HG = anomaliasdayHG.sel(time=anomaliasdayHG.time.isin(lista_fechas_360))

# %%
prom_anomCAO_HG = anomsCAO_HG.mean(dim='time')
prom_anomCAO_HG
# Out:
# <xarray.DataArray 'tas' ()> Size: 8B
# array(-6.71771759)

# %% [markdown]
# ##### **<font color="olive"> Geopotencial </font>**

# %% [markdown]
# ##### **<font color="olive"> Concat de índice >1 y valores de gph </font>**

# %%
idxp_zg_file = 'datasetsok/zg500_idx_std+.nc'
idxp_zg_ds = xr.open_dataset(idxp_zg_file)
idxp_zg = idxp_zg_ds['zg500']
idxp_zg['time'] = idxp_zg.time.dt.floor("D")

# %% [markdown]
# ##### **<font color="olive"> Temperatura e índice >1 (con valores de gph) </font>**

# %%
missing_times = np.setdiff1d(idxp_zg.time.values, anomaliasdayHG.time.values)
# print(missing_times)
len(missing_times)
# Out:
# 0

# %% [markdown]
# ##### **<font color="olive"> Concat de índice <-1 y valores de gph </font>**

# %%
idxn_zg_file = 'datasetsok/zg500_idx_std-.nc'
idxn_zg_ds = xr.open_dataset(idxn_zg_file)
idxn_zg = idxn_zg_ds['zg500']
idxp_zg['time'] = idxp_zg.time.dt.floor("D")

# %% [markdown]
# ##### **<font color="olive"> Temperatura e índice <-1 (con valores de gph) </font>**

# %%
missing_times = np.setdiff1d(idxp_zg.time.values, anomaliasdayHG.time.values)
# print(missing_times)
len(missing_times)
# Out:
# 0

# %%
tas_idxp=anomaliasdayHG.sel(time=idxp_zg.time.values)

# %%
tas_idxn=anomaliasdayHG.sel(time=idxn_zg.time.values)

# %%
tas_pos_mean = tas_idxp.to_series()
tas_neg_mean = tas_idxn.to_series()

dfHG = pd.DataFrame({
    "Anomalía": pd.concat([tas_pos_mean, tas_neg_mean]),
    "Fase": (
        ["PNA+"] * len(tas_pos_mean) +
        ["PNA-"] * len(tas_neg_mean)
    )
})

# %%
# Separar los datos por fase
pos_data = dfHG[dfHG["Fase"] == "PNA+"]["Anomalía"]
neg_data = dfHG[dfHG["Fase"] == "PNA-"]["Anomalía"]

plt.figure(figsize=(7, 4))
sns.kdeplot(pos_data, label="PNA positivo", color="red", fill=True, linewidth=1.5, alpha=0.6)
sns.kdeplot(neg_data, label="PNA negativo", color="blue", fill=True, linewidth=1.5, alpha=0.6)

valor_prom_anom = prom_anomCAO_HG.item()
# Agregar línea vertical con el valor del promedio
plt.axvline(valor_prom_anom, color="black", linestyle="--", linewidth=2, label=f"Media HadGEM3 = {valor_prom_anom:.2f}")

lineplot_setup(pos_data.min(), pos_data.max(), 
               xlab='Anomalía de temperatura (°C)', ylab='Densidad',
               title='Anomalías de temperatura por fase de PNA')

# %%
# Separar datos por fase para dfHG (tas)
pos_hg = dfHG[dfHG["Fase"] == "PNA+"]["Anomalía"]
neg_hg = dfHG[dfHG["Fase"] == "PNA-"]["Anomalía"]

# Separar datos por fase para df (t2m)
pos_t2m = df[df["Fase"] == "PNA+"]["Anomalía"]
neg_t2m = df[df["Fase"] == "PNA-"]["Anomalía"]

# Crear figura con dos subplots
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

# --- Panel izquierdo: tas (HadGEM3) ---
sns.kdeplot(pos_hg, label="PNA+", color="darkblue", fill=True, linewidth=1.5, alpha=0.7, ax=axes[0])
sns.kdeplot(neg_hg, label="PNA-", color="darkred", fill=True, linewidth=1.5, alpha=0.6, ax=axes[0])
prom_anomHG = prom_anomCAO_HG.item()
axes[0].axvline(prom_anomHG, color="black", linestyle="--", linewidth=2, label=f"TmeanCAOS= {prom_anomHG:.2f}")

# Aplicar configuración al subplot
lineplot_setup(
    xmin=pos_hg.min()-1,
    xmax=neg_hg.max()+2,
    xlab='Anomalía de temperatura (°C)',
    ylab='Densidad',
    title='Anomalías de temperatura por fase de PNA \n HadGEM3',
    ax=axes[0]
)

axes[0].legend()

# --- Panel derecho: t2m (ERA5) ---
sns.kdeplot(pos_t2m, label="PNA+", color="darkblue", fill=True, linewidth=1.5, alpha=0.7, ax=axes[1])
sns.kdeplot(neg_t2m, label="PNA-", color="darkred", fill=True, linewidth=1.5, alpha=0.6, ax=axes[1])
prom_anomE5 = prom_anomCAO_E5.item()
axes[1].axvline(prom_anomE5, color="black", linestyle="--", linewidth=2, label=f"TmeanCAOS = {prom_anomE5:.2f}")

# Aplicar configuración al subplot
lineplot_setup(
    xmin=pos_hg.min()-1,
    xmax=neg_hg.max()+2,
    xlab='Anomalía de temperatura (°C)',
    ylab='Densidad',
    title='Anomalías de temperatura por fase de PNA \n ERA5',
    ax=axes[1]
)

axes[1].legend()

# Título general y layout
plt.show()
