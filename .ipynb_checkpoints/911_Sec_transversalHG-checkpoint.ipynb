# %% [markdown]
# ----
# ## **<font color="crimson"> Ya bien </font>**

# %%
pip install jsmetrics
# Out:
# Requirement already satisfied: jsmetrics in /home/jovyan/.local/lib/python3.11/site-packages (0.2.7)
# Requirement already satisfied: numpy<=1.26.4,>=1.21.2 in /home/jovyan/.local/lib/python3.11/site-packages (from jsmetrics) (1.26.4)
# Requirement already satisfied: pandas>=1.4 in /opt/conda/lib/python3.11/site-packages (from jsmetrics) (2.2.3)
# Requirement already satisfied: matplotlib>=3.3.2 in /opt/conda/lib/python3.11/site-packages (from jsmetrics) (3.9.2)
# Collecting xarray>=2023.1.0 (from jsmetrics)
#   Downloading xarray-2025.11.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: scipy>=1.5.3 in /opt/conda/lib/python3.11/site-packages (from jsmetrics) (1.14.1)
# Requirement already satisfied: dask[array] in /home/jovyan/.local/lib/python3.11/site-packages (from jsmetrics) (2024.10.0)
# Requirement already satisfied: netCDF4>=1.5.5.1 in /home/jovyan/.local/lib/python3.11/site-packages (from jsmetrics) (1.7.1.post2)
# Requirement already satisfied: bottleneck in /home/jovyan/.local/lib/python3.11/site-packages (from jsmetrics) (1.4.2)
# Requirement already satisfied: cf-xarray>=0.6.1 in /home/jovyan/.local/lib/python3.11/site-packages (from jsmetrics) (0.9.5)
# Requirement already satisfied: Shapely in /opt/conda/lib/python3.11/site-packages (from jsmetrics) (2.0.6)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.3.2->jsmetrics) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.3.2->jsmetrics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.3.2->jsmetrics) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.3.2->jsmetrics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.3.2->jsmetrics) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.3.2->jsmetrics) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.3.2->jsmetrics) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.3.2->jsmetrics) (2.8.2)
# Collecting cftime (from netCDF4>=1.5.5.1->jsmetrics)
#   Using cached cftime-1.6.5-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from netCDF4>=1.5.5.1->jsmetrics) (2023.7.22)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.4->jsmetrics) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.4->jsmetrics) (2024.2)
# Collecting packaging>=20.0 (from matplotlib>=3.3.2->jsmetrics)
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: click>=8.1 in /home/jovyan/.local/lib/python3.11/site-packages (from dask[array]->jsmetrics) (8.1.7)
# Requirement already satisfied: cloudpickle>=3.0.0 in /home/jovyan/.local/lib/python3.11/site-packages (from dask[array]->jsmetrics) (3.1.0)
# Requirement already satisfied: fsspec>=2021.09.0 in /opt/conda/lib/python3.11/site-packages (from dask[array]->jsmetrics) (2024.9.0)
# Requirement already satisfied: partd>=1.4.0 in /home/jovyan/.local/lib/python3.11/site-packages (from dask[array]->jsmetrics) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.11/site-packages (from dask[array]->jsmetrics) (6.0.1)
# Collecting toolz>=0.10.0 (from dask[array]->jsmetrics)
#   Using cached toolz-1.1.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /opt/conda/lib/python3.11/site-packages (from dask[array]->jsmetrics) (6.8.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib-metadata>=4.13.0->dask[array]->jsmetrics) (3.17.0)
# Requirement already satisfied: locket in /home/jovyan/.local/lib/python3.11/site-packages (from partd>=1.4.0->dask[array]->jsmetrics) (1.0.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.2->jsmetrics) (1.16.0)
# Downloading xarray-2025.11.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 4.5 MB/s eta 0:00:0000:0100:01
# Using cached packaging-25.0-py3-none-any.whl (66 kB)
# Using cached toolz-1.1.0-py3-none-any.whl (58 kB)
# Using cached cftime-1.6.5-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.7 MB)
# Installing collected packages: toolz, packaging, cftime, xarray
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.2
#     Uninstalling packaging-23.2:
#       Successfully uninstalled packaging-23.2
# Successfully installed cftime-1.6.5 packaging-25.0 toolz-1.1.0 xarray-2025.11.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install cartopy
# Out:
# Collecting cartopy
#   Using cached cartopy-0.25.0-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: numpy>=1.23 in /home/jovyan/.local/lib/python3.11/site-packages (from cartopy) (1.26.4)
# Requirement already satisfied: matplotlib>=3.6 in /opt/conda/lib/python3.11/site-packages (from cartopy) (3.9.2)
# Requirement already satisfied: shapely>=2.0 in /opt/conda/lib/python3.11/site-packages (from cartopy) (2.0.6)
# Requirement already satisfied: packaging>=21 in /opt/conda/lib/python3.11/site-packages (from cartopy) (25.0)
# Collecting pyshp>=2.3 (from cartopy)
#   Using cached pyshp-3.0.2.post1-py3-none-any.whl.metadata (64 kB)
# Requirement already satisfied: pyproj>=3.3.1 in /opt/conda/lib/python3.11/site-packages (from cartopy) (3.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy) (1.4.7)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy) (2.8.2)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from pyproj>=3.3.1->cartopy) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.6->cartopy) (1.16.0)
# Using cached cartopy-0.25.0-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (11.8 MB)
# Using cached pyshp-3.0.2.post1-py3-none-any.whl (58 kB)
# Installing collected packages: pyshp, cartopy
# Successfully installed cartopy-0.25.0 pyshp-3.0.2.post1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install h5netcdf
# Out:
# Collecting h5netcdf
#   Using cached h5netcdf-1.7.3-py3-none-any.whl.metadata (13 kB)
# Collecting h5py (from h5netcdf)
#   Using cached h5py-3.15.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from h5netcdf) (25.0)
# Requirement already satisfied: numpy>=1.21.2 in /home/jovyan/.local/lib/python3.11/site-packages (from h5py->h5netcdf) (1.26.4)
# Using cached h5netcdf-1.7.3-py3-none-any.whl (56 kB)
# Using cached h5py-3.15.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (4.7 MB)
# Installing collected packages: h5py, h5netcdf
# Successfully installed h5netcdf-1.7.3 h5py-3.15.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install netcdf4
# Out:
# Requirement already satisfied: netcdf4 in /home/jovyan/.local/lib/python3.11/site-packages (1.7.1.post2)
# Requirement already satisfied: cftime in /opt/conda/lib/python3.11/site-packages (from netcdf4) (1.6.5)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from netcdf4) (2023.7.22)
# Requirement already satisfied: numpy in /home/jovyan/.local/lib/python3.11/site-packages (from netcdf4) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install cartopy
# Out:
# Requirement already satisfied: cartopy in /opt/conda/lib/python3.11/site-packages (0.25.0)
# Requirement already satisfied: numpy>=1.23 in /home/jovyan/.local/lib/python3.11/site-packages (from cartopy) (1.26.4)
# Requirement already satisfied: matplotlib>=3.6 in /opt/conda/lib/python3.11/site-packages (from cartopy) (3.9.2)
# Requirement already satisfied: shapely>=2.0 in /opt/conda/lib/python3.11/site-packages (from cartopy) (2.0.6)
# Requirement already satisfied: packaging>=21 in /opt/conda/lib/python3.11/site-packages (from cartopy) (25.0)
# Requirement already satisfied: pyshp>=2.3 in /opt/conda/lib/python3.11/site-packages (from cartopy) (3.0.2.post1)
# Requirement already satisfied: pyproj>=3.3.1 in /opt/conda/lib/python3.11/site-packages (from cartopy) (3.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy) (1.4.7)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.6->cartopy) (2.8.2)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from pyproj>=3.3.1->cartopy) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.6->cartopy) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xarray
# Out:
# Requirement already satisfied: xarray in /opt/conda/lib/python3.11/site-packages (2025.11.0)
# Requirement already satisfied: numpy>=1.26 in /home/jovyan/.local/lib/python3.11/site-packages (from xarray) (1.26.4)
# Requirement already satisfied: packaging>=24.1 in /opt/conda/lib/python3.11/site-packages (from xarray) (25.0)
# Requirement already satisfied: pandas>=2.2 in /opt/conda/lib/python3.11/site-packages (from xarray) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas>=2.2->xarray) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=2.2->xarray) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas>=2.2->xarray) (2024.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.2->xarray) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install cftime
# Out:
# Requirement already satisfied: cftime in /opt/conda/lib/python3.11/site-packages (1.6.5)
# Requirement already satisfied: numpy>=1.21.2 in /home/jovyan/.local/lib/python3.11/site-packages (from cftime) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xarray
# Out:
# Requirement already satisfied: xarray in /opt/conda/lib/python3.11/site-packages (2025.11.0)
# Requirement already satisfied: numpy>=1.26 in /home/jovyan/.local/lib/python3.11/site-packages (from xarray) (1.26.4)
# Requirement already satisfied: packaging>=24.1 in /opt/conda/lib/python3.11/site-packages (from xarray) (25.0)
# Requirement already satisfied: pandas>=2.2 in /opt/conda/lib/python3.11/site-packages (from xarray) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas>=2.2->xarray) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=2.2->xarray) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas>=2.2->xarray) (2024.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.2->xarray) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import xarray as xr
import numpy as np
import cftime
import jsmetrics
import jsmetrics.metrics.jet_statistics as jet_statistics
import matplotlib.pyplot as plt
import datetime
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.util import add_cyclic_point
import math
from matplotlib.ticker import FuncFormatter

# %%
# Función para mapear contourf con contour
def contour(data,contourdata,levels=np.arange(0,11),ccmap='PuBu',extend='max',limite_NS=42,clevels=np.arange(230,300,15),titulo='OLR y pr',cbarlabel='pr  [mm day$^{-1}$]'):
    lons,lats=data.lon,data.lat
    data, lon = add_cyclic_point(data, coord=lons)
    contourdata, lon = add_cyclic_point(contourdata, coord=lons)
    fig = plt.figure(figsize=(10, 6))
    ax = plt.axes(projection=ccrs.Robinson())
    ax.coastlines()
    ax.add_feature(cfeature.BORDERS, linestyle=':')
    cs=ax.contourf(lon,lats,data,levels=levels,cmap=ccmap,extend=extend,transform=ccrs.PlateCarree(),alpha=0.9)
    cc=ax.contour(lon,lats,contourdata,levels=clevels,colors='k',transform=ccrs.PlateCarree())
    ax.clabel(cc, cc.levels, inline=True, fontsize=10)
    ax.set_extent([-180,180, -limite_NS, limite_NS], crs=ccrs.PlateCarree())
    gl=ax.gridlines(draw_labels=True,color='gray', alpha=0.5, linestyle='--')
    gl.top_labels = False
    gl.right_labels = True
    gl.xlabel_style = {'size': 13}
    gl.ylabel_style = {'size': 13}
    plt.title(titulo,fontsize=13)
    plt.tight_layout()
    plt.subplots_adjust(bottom=0.1)
    cbar=plt.colorbar(cs,orientation='horizontal',fraction=0.046, pad=0.06)
    cbar.ax.set_xlabel(cbarlabel)

# %%
def lineplot_setup(xmin,xmax,xlab,ylab,ymin=None,ymax=None,title=None,legend=False):
    # especificar limites minimos y maximos del grafico
    plt.xlim([xmin,xmax])
    plt.ylim([ymin,ymax])
    # cuadrilla interna del grafico
    plt.grid(linestyle='--',alpha=0.66)
    plt.minorticks_on()
    # hacer las etiquetas de ambos ejes mas grandes
    plt.xticks(fontsize=8)
    plt.yticks(fontsize=8)
    plt.xlabel(xlab,fontsize=10)
    plt.ylabel(ylab,fontsize=10)
    plt.title(title,fontsize=11)
    if legend:
        plt.legend(fancybox=True,shadow=True,fontsize=8)

# %% [markdown]
# <a name='title'></a>
#  **<font color="Purple"> Funciones </font>**
# ---

# %% [markdown]
# ###### 1. Primer paso es subir los archivos
# ###### 2. Abrir archivos y seleccionar variables a usar

# %%
#Seleccionar archivos del historical
u_filename='datasets/ua_Amon_HadGEM3-GC31-LL_historical_r1i1p1f3_gn_195001-201412.nc'

# %%
# Seleccionar variables del archivo historical
u_ds=xr.open_dataset(u_filename)
ua50=u_ds['ua']  #viento zonal

# %%
ua = ua50.sel(time=ua50.time.dt.year >= 1979, drop=True)
ua
# Out:
# <xarray.DataArray 'ua' (time: 432, plev: 19, lat: 145, lon: 192)> Size: 914MB
# [228510720 values with dtype=float32]
# Coordinates:
#   * time     (time) object 3kB 1979-01-16 00:00:00 ... 2014-12-16 00:00:00
#   * plev     (plev) float64 152B 1e+05 9.25e+04 8.5e+04 ... 1e+03 500.0 100.0
#   * lat      (lat) float64 1kB -90.0 -88.75 -87.5 -86.25 ... 87.5 88.75 90.0
#   * lon      (lon) float64 2kB 0.0 1.875 3.75 5.625 ... 352.5 354.4 356.2 358.1
# Attributes:
#     standard_name:  eastward_wind
#     long_name:      Eastward Wind
#     comment:        Zonal wind (positive in a eastward direction).
#     units:          m s-1
#     original_name:  mo: (stash: m01s30i201, blev: [1000.0, 925.0, 850.0, 700....
#     cell_methods:   time: mean
#     cell_measures:  area: areacella
#     history:        2019-06-19T11:57:01Z altered by CMOR: replaced missing va...

# %%
np.min(ua)
# Out:
# <xarray.DataArray 'ua' ()> Size: 8B
# array(-84.15942383)
# Attributes:
#     standard_name:  eastward_wind
#     long_name:      Eastward Wind
#     comment:        Zonal wind (positive in a eastward direction).
#     units:          m s-1
#     original_name:  mo: (stash: m01s30i201, blev: [1000.0, 925.0, 850.0, 700....
#     cell_methods:   time: mean
#     cell_measures:  area: areacella
#     history:        2019-06-19T11:57:01Z altered by CMOR: replaced missing va...

# %% [markdown]
# ERA5

# %%
ue5_filename='datasets/sec_trans_ERA5'

# %%
u_dsE5=xr.open_dataset(ue5_filename)

# %%
u_dsE5
# Out:
# <xarray.Dataset> Size: 75kB
# Dimensions:         (pressure_level: 14, latitude: 147, season: 4)
# Coordinates:
#   * pressure_level  (pressure_level) float64 112B 1e+03 925.0 ... 70.0 50.0
#   * latitude        (latitude) float64 1kB 49.5 48.75 48.0 ... -59.25 -60.0
#   * season          (season) <U3 48B 'DJF' 'JJA' 'MAM' 'SON'
# Data variables:
#     anual           (pressure_level, latitude) float32 8kB ...
#     estación        (season, pressure_level, latitude) float32 33kB ...
#     OND             (pressure_level, latitude) float32 8kB ...
#     NDJ             (pressure_level, latitude) float32 8kB ...
#     DJF             (pressure_level, latitude) float32 8kB ...
#     JFM             (pressure_level, latitude) float32 8kB ...

# %% [markdown]
# ###### <h1  style="color:rebeccapurple; font-size:17px;"><i> Sección transversal del jet subtropical </i> </h1>
# #####   - `Anual`
# #####   - `Estacional`
# #####   - `Por meses`

# %%
def transversal_anual (ua,nivel_A,nivel_B):
    """
    Esta función genera la sección trasnversal del jet entre dos niveles de presión elegidos
    ua: set de datos
    nivel_A: mayor presión 
    nivel_B: menor presión
    """
    sección = ua.sel(plev=slice(nivel_A, nivel_B))
    ua_clima = sección.groupby('time.year').mean(dim=['time','lon']) #checar si no hay problema de hacer los mean al mismo tiempo
    año = ua_clima.mean(dim='year')
    season = sección.groupby('time.season').mean(dim=['time','lon'])
    mensual = sección.groupby('time.month').mean(dim=['time','lon'])
    
    #estos o por estacion
    OND = mensual.sel(month=[10, 11, 12]).mean(dim='month')
    NDJ = mensual.sel(month=[11, 12, 1]).mean(dim='month')
    DJF = mensual.sel(month=[12, 1, 2]).mean(dim='month')
    JFM = mensual.sel(month=[1, 2, 3]).mean(dim='month')

    return {'anual':año,'estación':season,'OND': OND, 'NDJ': NDJ, 'DJF': DJF, 'JFM': JFM} 
#LUEGO TENGO QUE LLAMAR LA FUNCIÓN DE CONTROURF PARA CADA UNO

# %%
transversales = transversal_anual(ua,100000,5000)

# %%
anual_trans = transversales['anual']
DJF_trans = transversales['DJF']

# %%
def pa_to_hpa(x, pos):
    return f'{int(x/100)}'

# %%
anual_trans_l = anual_trans.sel(lat=slice(-50,50))
DJF_trans_l = DJF_trans.sel(lat=slice(-50,50))

# %%
anual_trans = u_dsE5.anual
DJF_trans = u_dsE5.DJF

# %%
anual_transE5 = anual_trans.sel(latitude=slice(50,-50))
DJF_transE5 = DJF_trans.sel(latitude=slice(50,-50))

# %%
plt.figure(figsize=(14,6),dpi=150)
plt.subplots_adjust(wspace=0.30)

# anual ---------------------------------------------------------------------------------------------------------------------------
plt.subplot(1,2,1)
plt.contourf(anual_transE5.latitude,anual_transE5.pressure_level,anual_transE5,levels=np.arange(np.min(anual_transE5),41,3),cmap='cividis',extend='both')
plt.gca().invert_yaxis()
plt.colorbar(label='Velocidad del viento (m/s)')
plt.title('a$)$ Anual en ERA5 (1979-2024) ',fontstyle='italic',fontsize=14)
plt.xlabel('Latitud',fontsize=13)
plt.ylabel('Presión (hPa)',fontsize=13)
plt.minorticks_on()
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(linestyle='--',alpha=0.66,linewidth=0.5)
# plt.gca().yaxis.set_major_formatter(FuncFormatter(pa_to_hpa))

# djf ------------------------------------------------------------------------------------------------------------------------------------------------------

plt.subplot(1,2,2)
plt.contourf(DJF_transE5.latitude,DJF_transE5.pressure_level,DJF_transE5,levels=np.arange(np.min(DJF_transE5),41,3),cmap='cividis',extend='both')
plt.gca().invert_yaxis()
plt.colorbar(label='Velocidad del viento (m/s)')
plt.title('b$)$ DJF en ERA5 (1979-2024)',fontstyle='italic',fontsize=14)
plt.xlabel('Latitud',fontsize=13)
plt.ylabel('Presión (hPa)',fontsize=13)
plt.minorticks_on()
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(linestyle='--',alpha=0.66,linewidth=0.5)
# plt.gca().yaxis.set_major_formatter(FuncFormatter(pa_to_hpa))

plt.subplots_adjust(top=.79)
plt.suptitle('Sección transversal del STJ', fontsize=14, color="k", fontstyle='italic', fontweight='bold')
plt.savefig('3_Seccion_transversalERA5.png')

# %%
plt.figure(figsize=(14,6),dpi=150)
plt.subplots_adjust(wspace=0.35)

# anual ---------------------------------------------------------------------------------------------------------------------------
plt.subplot(1,2,1)
plt.contourf(anual_trans_l.lat,anual_trans_l.plev,anual_trans_l,levels=np.arange(np.min(anual_trans_l),41,3),cmap='cividis',extend='both')
plt.gca().invert_yaxis()
plt.colorbar(label='Velocidad del viento (m/s)')
plt.title('a$)$ Anual en HadGEM3 (1950-2014) ',fontstyle='italic',fontsize=14)
plt.xlabel('Latitud',fontsize=13)
plt.ylabel('Presión (hPa)',fontsize=13)
plt.minorticks_on()
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(linestyle='--',alpha=0.66,linewidth=0.5)
plt.gca().yaxis.set_major_formatter(FuncFormatter(pa_to_hpa))

# djf ------------------------------------------------------------------------------------------------------------------------------------------------------

plt.subplot(1,2,2)
plt.contourf(DJF_trans_l.lat,DJF_trans_l.plev,DJF_trans_l,levels=np.arange(np.min(anual_trans_l),41,3),cmap='cividis',extend='both')
plt.gca().invert_yaxis()
plt.colorbar(label='Velocidad del viento (m/s)')
plt.title('b$)$ DJF en HadGEM3 (1950-2014)',fontstyle='italic',fontsize=14)
plt.xlabel('Latitud',fontsize=13)
plt.ylabel('Presión (hPa)',fontsize=13)
plt.minorticks_on()
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(linestyle='--',alpha=0.66,linewidth=0.5)
plt.gca().yaxis.set_major_formatter(FuncFormatter(pa_to_hpa))

plt.subplots_adjust(top=.79)
plt.suptitle('Sección transversal del STJ', fontsize=14, color="k", fontstyle='italic', fontweight='bold')
plt.savefig('3_Seccion_transversalHG.png')

# %%
plt.figure(figsize=(10, 9), dpi=150)
plt.subplots_adjust(wspace=0.35,hspace=0.35)

# Subplot 1 ANUAL HadGEM
plt.subplot(2, 2, 1)
plt.contourf(anual_trans_l.lat,anual_trans_l.plev,anual_trans_l,levels=np.arange(-5,41,5),cmap='cividis',extend='both')
plt.gca().invert_yaxis()
plt.colorbar(label='Velocidad del viento (m/s)')
plt.title('a$)$ Anual en HadGEM3 \n(1979-2014) ',fontstyle='italic',fontsize=14)
plt.xlabel('Latitud',fontsize=12)
plt.ylabel('Presión (hPa)',fontsize=13)
plt.minorticks_on()
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(linestyle='--',alpha=0.66,linewidth=0.5)
plt.gca().yaxis.set_major_formatter(FuncFormatter(pa_to_hpa))

# Subplot 2 ANUAL ERA5
plt.subplot(2, 2, 2) 
plt.contourf(anual_transE5.latitude,anual_transE5.pressure_level,anual_transE5,levels=np.arange(-5,41,5),cmap='cividis',extend='both')
plt.gca().invert_yaxis()
plt.colorbar(label='Velocidad del viento (m/s)')
plt.title('b$)$ Anual en ERA5 \n(1979-2024) ',fontstyle='italic',fontsize=14)
plt.xlabel('Latitud',fontsize=12)
plt.ylabel('Presión (hPa)',fontsize=13)
plt.minorticks_on()
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(linestyle='--',alpha=0.66,linewidth=0.5)

# Subplot 3 DJF JOYA
plt.subplot(2,2,3)
plt.contourf(DJF_trans_l.lat,DJF_trans_l.plev,DJF_trans_l,levels=np.arange(-5,41,5),cmap='cividis',extend='both')
plt.gca().invert_yaxis()
plt.colorbar(label='Velocidad del viento (m/s)')
plt.title('c$)$ DJF en HadGEM3 \n(1979-2014)',fontstyle='italic',fontsize=14)
plt.xlabel('Latitud',fontsize=12)
plt.ylabel('Presión (hPa)',fontsize=13)
plt.minorticks_on()
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(linestyle='--',alpha=0.66,linewidth=0.5)
plt.gca().yaxis.set_major_formatter(FuncFormatter(pa_to_hpa))

# Subplot 4 DJF ERA 5
plt.subplot(2,2,4)
plt.contourf(DJF_transE5.latitude,DJF_transE5.pressure_level,DJF_transE5,levels=np.arange(-5,41,5),cmap='cividis',extend='both')
plt.gca().invert_yaxis()
plt.colorbar(label='Velocidad del viento (m/s)')
plt.title('d$)$ DJF en ERA5 \n(1979-2024)',fontstyle='italic',fontsize=14)
plt.xlabel('Latitud',fontsize=12)
plt.ylabel('Presión (hPa)',fontsize=13)
plt.minorticks_on()
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(linestyle='--',alpha=0.66,linewidth=0.5)

# plt.tight_layout(h_pad=4)
# plt.subplots_adjust(top=.87)
# plt.suptitle('Sección transversal del viento zonal',fontsize=14,color="k",fontstyle='italic',fontweight='bold');

plt.savefig('figsok/3_Sec_trans_HGE5.png')
